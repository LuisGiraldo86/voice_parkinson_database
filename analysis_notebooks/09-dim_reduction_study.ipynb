# %%
# Import required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from pymongo import MongoClient
import os
import warnings
import sys
warnings.filterwarnings('ignore')

# Set visualization style
plt.style.use('default')
sns.set_palette("husl")

library_path = os.path.abspath('..')
if library_path not in sys.path:
    sys.path.append(library_path)

PLOTS_PATH = os.path.join(library_path, 'plots')

print("Libraries imported successfully!")
print(f"Current working directory: {os.getcwd()}")
# Out:
# Libraries imported successfully!
# Current working directory: /home/luis/CGE/voice_db/analysis_notebooks

# %%
# Connect to MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["Diagnosis_Severity_PD_Voice"]
collection = db["studies"]

print("🔄 Loading studies from MongoDB...")
fields_to_extract = {
    "doi"             : 1, 
    "year"            : 1, 
    "study_id"        : 1,
    "ml_approaches"   : 1,
    '_id'             : 0
}  # 1 = include, 0 = exclude
studies_cursor = collection.find({}, fields_to_extract)
studies_list = list(studies_cursor)


print(f"📊 Total studies loaded: {len(studies_list)}")
print(f"📄 Sample document keys: {list(studies_list[0].keys()) if studies_list else 'No documents found'}")
# Out:
# 🔄 Loading studies from MongoDB...
# 📊 Total studies loaded: 381
# 📄 Sample document keys: ['year', 'doi', 'ml_approaches', 'study_id']

# %%
def get_dimensionality_reduction(experiment_list:list)->list:

    dim_reduc = []

    for experiment in experiment_list:
        reduction = experiment.get('dimensionality_reduction')
        if reduction is None:
            reduction = []
        dim_reduc += reduction

    return list(set(dim_reduc))

def experiments_with_dim_reduc(experiment_list: list)->int:

    count = 0
    for experiment in experiment_list:
        if experiment.get('dimensionality_reduction') is not None:
            count+=1
    return count

# %%
experiment_df = pd.DataFrame(studies_list)
experiment_df['num_experiments'] = experiment_df['ml_approaches'].apply(lambda x: len(x))
experiment_df['exp_with_dim_reduc'] = experiment_df['ml_approaches'].apply(lambda x: experiments_with_dim_reduc(x))
experiment_df.head()
# Out:
#    year                          doi  \
# 0  2020  10.1109/ACCESS.2020.2974008
# 1  2020                10.2196/18689
# 2  2020          10.3233/JIFS-179714
# 3  2020    10.1016/j.bbe.2019.05.005
# 4  2020            10.15439/2020F188
#
#                                        ml_approaches  \
# 0  [{'algorithm': 'Convolutional Neural Network: ...
# 1  [{'algorithm': 'Support Vector Machine', 'fram...
# 2  [{'algorithm': 'Support Vector Machine: Linear...
# 3  [{'algorithm': 'Support Vector Machine', 'fram...
# 4  [{'algorithm': 'Fine Tree', 'framework': 'MATL...
#
#                         study_id  num_experiments  exp_with_dim_reduc
# 0  10.1109/ACCESS.2020.2974008_1                9                   0
# 1                10.2196/18689_1                4                   0
# 2          10.3233/JIFS-179714_1                2                   0
# 3    10.1016/j.bbe.2019.05.005_2                4                   0
# 4            10.15439/2020F188_1               48                   0

# %%
num_experiments = experiment_df['num_experiments'].sum()
num_experiments_with_dim_reduc = experiment_df['exp_with_dim_reduc'].sum()

print(f"Total number of experiments: {num_experiments}")
print(f"Number of experiments with dimensionality reduction: {num_experiments_with_dim_reduc}")
print(f"NNumber of experiments without dimensionality reduction: {num_experiments-num_experiments_with_dim_reduc}")
print(f"Percentage of experiments with dimensionality reduction: {num_experiments_with_dim_reduc/num_experiments*100:.2f}%")
print(f"Number of papers: {experiment_df['doi'].nunique()}")
# Out:
# Total number of experiments: 2431
# Number of experiments with dimensionality reduction: 200
# NNumber of experiments without dimensionality reduction: 2231
# Percentage of experiments with dimensionality reduction: 8.23%
# Number of papers: 260

# %%
experiment_df['dimensionality_reduction'] = experiment_df['ml_approaches'].apply(
    lambda x: get_dimensionality_reduction(x)
)

dim_reduc_df = experiment_df.explode('dimensionality_reduction')
dim_reduc_df.head(7)
# Out:
#    year                           doi  \
# 0  2020   10.1109/ACCESS.2020.2974008
# 1  2020                 10.2196/18689
# 2  2020           10.3233/JIFS-179714
# 3  2020     10.1016/j.bbe.2019.05.005
# 4  2020             10.15439/2020F188
# 5  2020    10.1016/j.mehy.2020.109603
# 6  2020  10.1016/j.neucom.2020.03.058
#
#                                        ml_approaches  \
# 0  [{'algorithm': 'Convolutional Neural Network: ...
# 1  [{'algorithm': 'Support Vector Machine', 'fram...
# 2  [{'algorithm': 'Support Vector Machine: Linear...
# 3  [{'algorithm': 'Support Vector Machine', 'fram...
# 4  [{'algorithm': 'Fine Tree', 'framework': 'MATL...
# 5  [{'algorithm': 'Support Vector Machine', 'fram...
# 6  [{'algorithm': 'Gaussian Process: ARD Exponent...
#
#                          study_id  num_experiments  exp_with_dim_reduc  \
# 0   10.1109/ACCESS.2020.2974008_1                9                   0
# 1                 10.2196/18689_1                4                   0
# 2           10.3233/JIFS-179714_1                2                   0
# 3     10.1016/j.bbe.2019.05.005_2                4                   0
# 4             10.15439/2020F188_1               48                   0
# 5    10.1016/j.mehy.2020.109603_1                3                   0
# 6  10.1016/j.neucom.2020.03.058_1                4                   0
#
#   dimensionality_reduction
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN

# %%
dim_reduc_df['dimensionality_reduction'].value_counts()
# Out:
# dimensionality_reduction
# PCA                             19
# Kernel PCA                       2
# Linear Discriminant Analysis     1
# Singular Value Decomposition     1
# Name: count, dtype: int64

# %%
dim_reduc_df[~dim_reduc_df['dimensionality_reduction'].isna()].groupby('doi').size().shape[0]
# Out:
# 21

# %%
dim_reduc_df[~dim_reduc_df['dimensionality_reduction'].isna()].groupby('doi')\
.agg({'dimensionality_reduction': set}).explode('dimensionality_reduction')\
['dimensionality_reduction'].value_counts()
# Out:
# dimensionality_reduction
# PCA                             17
# Kernel PCA                       2
# Singular Value Decomposition     1
# Linear Discriminant Analysis     1
# Name: count, dtype: int64

# %%
dim_reduc_df[~dim_reduc_df['dimensionality_reduction'].isna()]
# Out:
#      year                                 doi  \
# 22   2020    10.1109/ICDABI51230.2020.9325709
# 53   2021     10.1109/ICMSS53060.2021.9673634
# 69   2021                    10.1002/cpe.6419
# 70   2021                10.1155/2021/8822069
# 83   2021          10.1007/s41060-020-00234-0
# 87   2021          10.1007/s41060-020-00234-0
# 89   2021        10.1016/j.ifacol.2021.10.286
# 95   2022            10.32604/cmc.2022.023124
# 107  2022                10.1155/2022/1487212
# 113  2022          10.1108/IJICC-10-2021-0226
# 206  2023         10.1016/j.procs.2023.01.007
# 220  2024          10.1007/s12553-023-00810-x
# 292  2025           10.3991/ijoe.v21i02.50503
# 301  2025         10.1038/s41598-025-96950-3
# 302  2025          10.1016/j.csbj.2025.06.022
# 310  2025           10.1177/18724981251353596
# 325  2025          10.1016/j.csbj.2025.06.022
# 347  2020          10.1007/s13534-020-00156-7
# 355  2023  10.1016/j.compbiolchem.2022.107788
# 361  2020        10.1007/978-3-030-31129-2_15
# 366  2024           10.1016/j.bbe.2024.08.009
# 371  2022                10.1155/2022/2793361
# 376  2025         10.1109/ACCESS.2025.3597851
#
#                                          ml_approaches  \
# 22   [{'algorithm': 'Adaptive Momentum Backpropagat...
# 53   [{'algorithm': 'Random Forest', 'framework': '...
# 69   [{'algorithm': 'Adaptive Linear k-SVM', 'frame...
# 70   [{'algorithm': 'Support Vector Machine: Linear...
# 83   [{'algorithm': 'Support Vector Machine: Linear...
# 87   [{'algorithm': 'Support Vector Machine: Linear...
# 89   [{'algorithm': 'Support Vector Machine: RBF', ...
# 95   [{'algorithm': 'Naive Bayes', 'framework': '',...
# 107  [{'algorithm': 'Fuzzy Convolution Bi-direction...
# 113  [{'algorithm': 'Fuzzy K-Nearest Neighbors', 's...
# 206  [{'algorithm': 'Logistic Regression', 'framewo...
# 220  [{'algorithm': 'XGBoost', 'framework': '', 'im...
# 292  [{'algorithm': 'Naive Bayes', 'framework': '',...
# 301  [{'algorithm': 'Support Vector Machine', 'vali...
# 302  [{'algorithm': 'Decision Tree', 'framework': '...
# 310  [{'algorithm': 'Stacking Ensemble (Base: Rando...
# 325  [{'algorithm': 'Decision Tree', 'framework': '...
# 347  [{'algorithm': 'Multilayer Perceptron', 'dimen...
# 355  [{'algorithm': 'Deep Belief Network: Adaptive ...
# 361  [{'algorithm': 'Extreme Learning Machine', 'fe...
# 366  [{'algorithm': 'Least Square Support Vector Ma...
# 371  [{'algorithm': 'Ensemble (Support Vector Machi...
# 376  [{'algorithm': 'Fused Neural Network', 'framew...
#
#                                  study_id  num_experiments  \
# 22     10.1109/ICDABI51230.2020.9325709_1                2
# 53      10.1109/ICMSS53060.2021.9673634_1                4
# 69                     10.1002/cpe.6419_1               16
# 70                 10.1155/2021/8822069_1                4
# 83           10.1007/s41060-020-00234-0_1               43
# 87           10.1007/s41060-020-00234-0_2               30
# 89         10.1016/j.ifacol.2021.10.286_1                8
# 95             10.32604/cmc.2022.023124_1               30
# 107                10.1155/2022/1487212_1                4
# 113          10.1108/IJICC-10-2021-0226_1                4
# 206         10.1016/j.procs.2023.01.007_1               12
# 220          10.1007/s12553-023-00810-x_1                6
# 292           10.3991/ijoe.v21i02.50503_1               12
# 301          10.1038/s41598-025-96950-3_1                4
# 302          10.1016/j.csbj.2025.06.022_1               60
# 310           10.1177/18724981251353596_1                2
# 325          10.1016/j.csbj.2025.06.022_2               60
# 347          10.1007/s13534-020-00156-7_2                1
# 355  10.1016/j.compbiolchem.2022.107788_1                2
# 361        10.1007/978-3-030-31129-2_15_1                1
# 366           10.1016/j.bbe.2024.08.009_1                2
# 371                10.1155/2022/2793361_1                1
# 376  10.1109/EICEEAI60672.2023.10590358_1                1
#
#      exp_with_dim_reduc      dimensionality_reduction
# 22                    1                           PCA
# 53                    4                           PCA
# 69                    4                           PCA
# 70                    4  Linear Discriminant Analysis
# 83                   11                           PCA
# 87                   10                           PCA
# 89                    4                           PCA
# 95                    6                           PCA
# 107                   4                    Kernel PCA
# 113                   4  Singular Value Decomposition
# 206                   4                           PCA
# 220                   6                    Kernel PCA
# 292                   6                           PCA
# 301                   4                           PCA
# 302                  60                           PCA
# 310                   1                           PCA
# 325                  60                           PCA
# 347                   1                           PCA
# 355                   2                           PCA
# 361                   1                           PCA
# 366                   1                           PCA
# 371                   1                           PCA
# 376                   1                           PCA

# %%
dim_reduc_df[~dim_reduc_df['dimensionality_reduction'].isna()].groupby('doi')\
.agg({'dimensionality_reduction': set})
# Out:
#                                           dimensionality_reduction
# doi
# 10.1002/cpe.6419                                             {PCA}
# 10.1007/978-3-030-31129-2_15                                 {PCA}
# 10.1007/s12553-023-00810-x                            {Kernel PCA}
# 10.1007/s13534-020-00156-7                                   {PCA}
# 10.1007/s41060-020-00234-0                                   {PCA}
# 10.1016/j.bbe.2024.08.009                                    {PCA}
# 10.1016/j.compbiolchem.2022.107788                           {PCA}
# 10.1016/j.csbj.2025.06.022                                   {PCA}
# 10.1016/j.ifacol.2021.10.286                                 {PCA}
# 10.1016/j.procs.2023.01.007                                  {PCA}
# 10.1038/s41598-025-96950-3                                   {PCA}
# 10.1108/IJICC-10-2021-0226          {Singular Value Decomposition}
# 10.1109/ACCESS.2025.3597851                                  {PCA}
# 10.1109/ICDABI51230.2020.9325709                             {PCA}
# 10.1109/ICMSS53060.2021.9673634                              {PCA}
# 10.1155/2021/8822069                {Linear Discriminant Analysis}
# 10.1155/2022/1487212                                  {Kernel PCA}
# 10.1155/2022/2793361                                         {PCA}
# 10.1177/18724981251353596                                    {PCA}
# 10.32604/cmc.2022.023124                                     {PCA}
# 10.3991/ijoe.v21i02.50503                                    {PCA}
